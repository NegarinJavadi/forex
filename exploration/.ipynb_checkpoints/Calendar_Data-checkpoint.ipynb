# %%
import sys
sys.path.append("../")

import pandas as pd
import plotly.graph_objects as go
from dateutil import parser
import datetime as dt

from api.oanda_api import OandaApi
from infrastructure.instrument_collection import instrumentCollection as ic
from db.db import DataDB

# %%
database = DataDB()

# %%
ic.LoadInstrumentsDB()

# %%
pairs = []
for pair, val in ic.instruments_dict.items():
    if val.ins_type == "CURRENCY" and "USD" in pair:
        pairs.append(pair)

# %%
pairs
# Out:
# ['USD_CHF',
#  'USD_THB',
#  'USD_JPY',
#  'NZD_USD',
#  'USD_SGD',
#  'USD_CAD',
#  'AUD_USD',
#  'USD_TRY',
#  'USD_NOK',
#  'USD_CNH',
#  'USD_PLN',
#  'USD_ZAR',
#  'USD_CZK',
#  'USD_DKK',
#  'USD_SEK',
#  'GBP_USD',
#  'USD_MXN',
#  'USD_HUF',
#  'USD_HKD',
#  'EUR_USD']

# %%
data = []
api = OandaApi()
for p in pairs:
    print(p)
    d_temp = api.get_candles_df(pair_name=p, granularity="D", count=400)
    d_temp['gain'] = ((d_temp['mid-c'] - d_temp['mid-o']) / d_temp['mid-c']) * 100
    d_temp['pair'] = p
    if '_USD' in p:
        d_temp['gain'] = d_temp['gain'] * -1
    data.append(d_temp)
candles_df = pd.concat(data)
candles_df.reset_index(drop=True, inplace=True)
candles_df.time = candles_df.time.dt.date
# Out:
# USD_CHF
# USD_THB
# USD_JPY
# NZD_USD
# USD_SGD
# USD_CAD
# AUD_USD
# USD_TRY
# USD_NOK
# USD_CNH
# USD_PLN
# USD_ZAR
# USD_CZK
# USD_DKK
# USD_SEK
# GBP_USD
# USD_MXN
# USD_HUF
# USD_HKD
# EUR_USD

# %%
candles_df.tail()
# Out:
#       volume        time    mid-o    mid-h    mid-l    mid-c    bid-o  \
# 7995   57279  2024-01-14  1.09474  1.09676  1.09336  1.09503  1.09463
# 7996  112047  2024-01-15  1.09488  1.09512  1.08621  1.08756  1.09471
# 7997  100485  2024-01-16  1.08738  1.08846  1.08446  1.08821  1.08704
# 7998  102050  2024-01-17  1.08824  1.09068  1.08468  1.08763  1.08813
# 7999   85492  2024-01-18  1.08746  1.08978  1.08657  1.08976  1.08729
#
#         bid-h    bid-l    bid-c    ask-o    ask-h    ask-l    ask-c      gain  \
# 7995  1.09668  1.09328  1.09495  1.09486  1.09683  1.09343  1.09511 -0.026483
# 7996  1.09505  1.08613  1.08747  1.09506  1.09529  1.08628  1.08764  0.673066
# 7997  1.08839  1.08439  1.08813  1.08771  1.08854  1.08454  1.08829 -0.076272
# 7998  1.09060  1.08460  1.08754  1.08835  1.09075  1.08475  1.08772  0.056085
# 7999  1.08970  1.08649  1.08966  1.08763  1.08986  1.08665  1.08986 -0.211056
#
#          pair
# 7995  EUR_USD
# 7996  EUR_USD
# 7997  EUR_USD
# 7998  EUR_USD
# 7999  EUR_USD

# %%
calendar_data = database.query_all(DataDB.CALENDAR_COLL)

# %%
calendar_data_df = pd.DataFrame.from_dict(calendar_data)

# %%
calendar_data_df.head()
# Out:
#         date    country             category                         event  \
# 0 2024-01-23  australia  business confidence       nab business confidence
# 1 2024-01-23      japan        interest rate    boj interest rate decision
# 2 2024-01-23      japan     balance of trade              balance of trade
# 3 2024-01-24    germany    manufacturing pmi  hcob manufacturing pmi flash
# 4 2024-01-24     canada        interest rate    boc interest rate decision
#
#           symbol actual  previous forecast
# 0       NABSCONF               -9       -7
# 1         BOJDTR            -0.1%    -0.1%
# 2         JNTBAL         ¥-776.9B  ¥ -200B
# 3  GERMANYMANPMI             43.3     44.0
# 4           CCLR               5%       5%

# %%
calendar_data_df.date = calendar_data_df.date.dt.date

# %%
calendar_data_df
# Out:
#            date    country                category  \
# 0    2024-01-23  australia     business confidence
# 1    2024-01-23      japan           interest rate
# 2    2024-01-23      japan        balance of trade
# 3    2024-01-24    germany       manufacturing pmi
# 4    2024-01-24     canada           interest rate
# ..          ...        ...                     ...
# 611  2024-01-30     france  gdp annual growth rate
# 612  2024-01-30      italy         gdp growth rate
# 613  2024-01-30      italy  gdp annual growth rate
# 614  2024-01-30  euro area         gdp growth rate
# 615  2024-01-30  euro area  gdp annual growth rate
#
#                             event         symbol actual  previous forecast
# 0         nab business confidence       NABSCONF               -9       -7
# 1      boj interest rate decision         BOJDTR            -0.1%    -0.1%
# 2                balance of trade         JNTBAL         ¥-776.9B  ¥ -200B
# 3    hcob manufacturing pmi flash  GERMANYMANPMI             43.3     44.0
# 4      boc interest rate decision           CCLR               5%       5%
# ..                            ...            ...    ...       ...      ...
# 611      gdp growth rate yoy prel       FRGEGDPY             0.6%     0.2%
# 612       gdp growth rate qoq adv       ITPIRLQS             0.1%     0.2%
# 613       gdp growth rate yoy adv       ITPIRLYS             0.1%    -0.3%
# 614     gdp growth rate qoq flash       EUGNEMUQ            -0.1%    -0.1%
# 615     gdp growth rate yoy flash       EUGNEMUY               0%     0.4%
#
# [616 rows x 8 columns]

# %%
calendar_data_df_cad = calendar_data_df[calendar_data_df.country == "canada"].copy()

# %%
calendar_data_df_cad.head(10)
# Out:
#           date country       category                       event symbol  \
# 4   2024-01-30  canada  interest rate  boc interest rate decision   CCLR
# 5   2024-01-30  canada  interest rate  boc monetary policy report   CCLR
# 26  2024-01-30  canada  interest rate  boc interest rate decision   CCLR
# 27  2024-01-30  canada  interest rate  boc monetary policy report   CCLR
# 48  2024-01-30  canada  interest rate  boc interest rate decision   CCLR
# 49  2024-01-30  canada  interest rate  boc monetary policy report   CCLR
# 70  2024-01-30  canada  interest rate  boc interest rate decision   CCLR
# 71  2024-01-30  canada  interest rate  boc monetary policy report   CCLR
# 92  2024-01-30  canada  interest rate  boc interest rate decision   CCLR
# 93  2024-01-30  canada  interest rate  boc monetary policy report   CCLR
#
#     actual  previous  forecast   orig_date
# 4      0.0       5.0       5.0  2024-01-24
# 5      0.0       0.0       0.0  2024-01-24
# 26     0.0       5.0       5.0  2024-01-24
# 27     0.0       0.0       0.0  2024-01-24
# 48     0.0       5.0       5.0  2024-01-24
# 49     0.0       0.0       0.0  2024-01-24
# 70     0.0       5.0       5.0  2024-01-24
# 71     0.0       0.0       0.0  2024-01-24
# 92     0.0       5.0       5.0  2024-01-24
# 93     0.0       0.0       0.0  2024-01-24

# %%
calendar_data_df_cad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 4 to 599
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      56 non-null     object
#  1   country   56 non-null     object
#  2   category  56 non-null     object
#  3   event     56 non-null     object
#  4   symbol    56 non-null     object
#  5   actual    56 non-null     float64
#  6   previous  56 non-null     float64
#  7   forecast  56 non-null     float64
# dtypes: float64(3), object(5)
# memory usage: 3.9+ KB

# %%
for col in ['actual', 'previous', 'forecast']:
    for sy in ['$', '%', 'B', 'K']:
        calendar_data_df_cad[col] = calendar_data_df_cad[col].str.replace(sy, "")
    calendar_data_df_cad[col].replace('', 0, inplace=True)
    calendar_data_df_cad[col] = calendar_data_df_cad[col].astype(float)

# %%
date_match= {}
for orig in calendar_data_df_cad.date.unique():
    d = orig
    tries = 0
    while d not in candles_df.time.values:
        d = d + dt.timedelta(days=1)
        tries += 1
        if tries > 5:
            print("Failed")
            break
    date_match[orig] = d
# Out:
# Failed

# %%
date_match
# Out:
# {datetime.date(2024, 1, 24): datetime.date(2024, 1, 30)}

# %%
calendar_data_df_cad['orig_date'] = calendar_data_df_cad.date
calendar_data_df_cad.date = [date_match[x] for x in calendar_data_df_cad.date]
